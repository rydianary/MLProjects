# %%
import networkx as nx
import matplotlib.pyplot as plt
import random
import copy

# Recreating the given graph
G=nx.Graph()
G.add_nodes_from(['AMS', 'BER', 'COL', 'LON', 'BRU', 'FRA','PAR', 'LYO', 'MIL', 'ROM', 'BAR', 'MAD'])

G.add_edge("AMS", "BER", time=364, cost=235)
G.add_edge("AMS", "COL", time=120, cost=40)
G.add_edge("AMS", "BRU", time=105, cost=48)
G.add_edge("BER", "AMS", time=364, cost=235)
G.add_edge("BER", "FRA", time=232, cost=125)
G.add_edge("COL", "AMS", time=120, cost=40)
G.add_edge("COL", "FRA", time=120, cost=40)
G.add_edge("FRA", "BER", time=232, cost=125)
G.add_edge("FRA", "COL", time=120, cost=40)
G.add_edge("FRA", "PAR", time=480, cost=345)
G.add_edge("FRA", "MIL", time=454, cost=240)
G.add_edge("BRU", "AMS", time=105, cost=48)
G.add_edge("BRU", "PAR", time=82, cost=80)
G.add_edge("LON", "PAR", time=136, cost=98)
G.add_edge("LON", "BRU", time=136, cost=98)
G.add_edge("PAR", "LON", time=136, cost=98)
G.add_edge("PAR", "BRU", time=82, cost=80)
G.add_edge("PAR", "FRA", time=480, cost=345)
G.add_edge("PAR", "LYO", time=112, cost=185)
G.add_edge("PAR", "BAR", time=390, cost=400)
G.add_edge("PAR", "MAD", time=225, cost=380)
G.add_edge("LYO", "PAR", time=112, cost=185)
G.add_edge("LYO", "MIL", time=176, cost=180)
G.add_edge("LYO", "BAR", time=200, cost=320)
G.add_edge("MIL", "FRA", time=454, cost=240)
G.add_edge("MIL", "ROM", time=168, cost=125)
G.add_edge("MIL", "LYO", time=176, cost=180)
G.add_edge("BAR", "PAR", time=390, cost=400)
G.add_edge("BAR", "LYO", time=200, cost=320)
G.add_edge("BAR", "MAD", time=150, cost=98)
G.add_edge("MAD", "PAR", time=225, cost=380)
G.add_edge("MAD", "BAR", time=150, cost=98)

# %%
def generate_path():
    node=random.choice(list(G.nodes()))
    path=[node]
    time=0
    cost=0
    unique=0
    while time < 4320: #72 hours
      # adjacent cities
      edges=list(G[node])
      # Remove unvisited nodes of cities
      unvisited_edges=[n for n in edges if n not in path]
      if not unvisited_edges:
          break
      next=random.choice(unvisited_edges)

      #get the time and cost values
      path.append(next)
      edge=G[node][next]
      time += edge['time']
      cost += edge['cost']

      # Move to the next node
      node=next

    return path, time, cost

# %%
def fitness_score(path):

    for i in range(len(path)-1):
      try:
        edge = G[path[i]][path[i+1]]
      except:
        return 0

    # cost of the route created
    cost = 1/sum(G[path[i]][path[i+1]]['cost'] for i in range(len(path)-1))
    unique_nodes = len(set(path))
    return cost + unique_nodes

# %%
# Create an individual chromosome
def create_individual():
    path, time, cost=generate_path()
    fitness=fitness_score(path)
    path_dict={'path': path, 'time': time, 'cost': cost, 'fitness': fitness}
    
    return path_dict

# %%
def firstGeneration(genSize):
  population=[]
  for i in range(genSize):
      path=create_individual()
      population.append(path)
  return population

# %%
def sorting_gen(paths):
    # fitness scores
    sorted_paths=sorted(paths, key=lambda x: x['fitness'], reverse=True)
    return sorted_paths

# %%
def calculate_time_and_cost(path):
    total_time=0
    total_cost=0
    for i in range(len(path)-1):

      try:
        edge=G[path[i]][path[i+1]]
      except:
        return 0, 0

      total_time += edge['time']
      total_cost += edge['cost']
    return total_time, total_cost

# %%
def single_point_crossover(path_1, path_2):
     # Choose a random point
    crossover_point=random.randint(1, len(path_1) - 1)
    
    # Start swapping the tails of the paths
    new_path_1=path_1['path'][:crossover_point] + path_2['path'][crossover_point:]
    new_path_2=path_2['path'][:crossover_point] + path_1['path'][crossover_point:]
    
    # Create the new individuals with with respective weights
    new_individual_1={'path': new_path_1, 'time': 0, 'cost': 0, 'fitness': 0}
    new_individual_2={'path': new_path_2, 'time': 0, 'cost': 0, 'fitness': 0}
    new_individual_1['time'], new_individual_1['cost']=calculate_time_and_cost(new_path_1)
    new_individual_2['time'], new_individual_2['cost']=calculate_time_and_cost(new_path_2)
    
    # Calculate the fitness score
    new_individual_1['fitness']=fitness_score(new_path_1)
    new_individual_2['fitness']=fitness_score(new_path_2)
    
    return new_individual_1, new_individual_2

# %%
 def breedPopulation(matingpool, eliteSize):
    nextGen=[]
    new_children=len(matingpool) - eliteSize

    for i in range (0, eliteSize):
      nextGen.append(matingpool[i])

    for i in range(0, new_children, 2):
      child1, child2=single_point_crossover(matingpool[i], matingpool[i+1])

      if child1['fitness'] != 0:
        nextGen.append(child1)
      
      if child2['fitness'] != 0:
        nextGen.append(child2)
    
    return nextGen

# %%
def mutateIndividual(path, mutation_rate):
    mutated=path
    if random.uniform(0, 1) < mutation_rate:
        # Choose two random positions 
        position1=random.randint(0, len(path['path']) - 1)
        position2=random.randint(0, len(path['path']) - 1)
        mutated['time']=0
        mutated['cost']=0
        mutated['fitness']=0
        # Swap the cities 
        path['path'][position1], path['path'][position2]=path['path'][position2], path['path'][position1]
        mutated['time'], mutated['cost']=calculate_time_and_cost(path)
        
        # Calculate the fitness score
        mutated['fitness']=fitness_score(mutated)
        mutated['fitness']=fitness_score(mutated)
    return mutated

# %%
def mutatePopulation(generation, mutationRate):
  mutatedGen=[]

  for i in range(0, len(generation)):
    mutatedIndividual=mutateIndividual(generation[i], mutationRate)
    mutatedGen.append(mutatedIndividual)
  return mutatedGen

# %%
def nextGeneration(currentGen, eliteSize, mutationRate):
    genRanked=sorting_gen(currentGen)
    children=breedPopulation(genRanked, eliteSize)
    nextGeneration=mutatePopulation(children, mutationRate)
    return nextGeneration

# %%
def geneticAlgorithm(popSize, eliteSize, mutationRate, generations):
    pop=firstGeneration(popSize)   
    for i in range(generations):
      pop=nextGeneration(pop, eliteSize, mutationRate)
      print("Distance from generation ", str(i+1), ": ", str(sorting_gen(pop)[0]['fitness']))
    
    print("Final distance: " + str(sorting_gen(pop)[0]))
    bestRoute=sorting_gen(pop)[0]
    return bestRoute

# %%
geneticAlgorithm(popSize=1000, eliteSize=150, mutationRate=0.1, generations=1000)
# Out:
# Distance from generation  1 :  12.000644329896907
# Distance from generation  2 :  12.000644329896907
# Distance from generation  3 :  12.000644329896907
# Distance from generation  4 :  11.00077399380805
# Distance from generation  5 :  11.00077399380805
# Distance from generation  6 :  11.00077399380805
# Distance from generation  7 :  11.00077399380805
# Distance from generation  8 :  11.00077399380805
# Distance from generation  9 :  11.000696378830083
# Distance from generation  10 :  11.000696378830083
# Distance from generation  11 :  11.000696378830083
# Distance from generation  12 :  11.000696378830083
# Distance from generation  13 :  11.000696378830083
# Distance from generation  14 :  11.000696378830083
# Distance from generation  15 :  11.000696378830083
# Distance from generation  16 :  11.000696378830083
# Distance from generation  17 :  11.000696378830083
# Distance from generation  18 :  11.000696378830083
# Distance from generation  19 :  11.000696378830083
# Distance from generation  20 :  11.000696378830083
# Distance from generation  21 :  11.000696378830083
# Distance from generation  22 :  11.000696378830083
# Distance from generation  23 :  11.000696378830083
# Distance from generation  24 :  11.000696378830083
# Distance from generation  25 :  11.000696378830083
# Distance from generation  26 :  11.000696378830083
# Distance from generation  27 :  11.000696378830083
# Distance from generation  28 :  11.000696378830083
# Distance from generation  29 :  11.000696378830083
# Distance from generation  30 :  11.000696378830083
# Distance from generation  31 :  11.000696378830083
# Distance from generation  32 :  11.000696378830083
# Distance from generation  33 :  11.000696378830083
# Distance from generation  34 :  11.000696378830083
# Distance from generation  35 :  11.000696378830083
# Distance from generation  36 :  11.000696378830083
# Distance from generation  37 :  11.000696378830083
# Distance from generation  38 :  11.000696378830083
# Distance from generation  39 :  11.000696378830083
# Distance from generation  40 :  11.000696378830083
# Distance from generation  41 :  11.000696378830083
# Distance from generation  42 :  11.000696378830083
# Distance from generation  43 :  11.000696378830083
# Distance from generation  44 :  11.000696378830083
# Distance from generation  45 :  11.000696378830083
# Distance from generation  46 :  11.000696378830083
# Distance from generation  47 :  11.000696378830083
# Distance from generation  48 :  11.000696378830083
# Distance from generation  49 :  11.000696378830083
# Distance from generation  50 :  11.000696378830083
# Distance from generation  51 :  11.000696378830083
# Distance from generation  52 :  11.000696378830083
# Distance from generation  53 :  11.000696378830083
# Distance from generation  54 :  11.000696378830083
# Distance from generation  55 :  11.000696378830083
# Distance from generation  56 :  11.000696378830083
# Distance from generation  57 :  11.000696378830083
# Distance from generation  58 :  11.000696378830083
# Distance from generation  59 :  11.000696378830083
# Distance from generation  60 :  11.000696378830083
# Distance from generation  61 :  11.000696378830083
# Distance from generation  62 :  11.000696378830083
# Distance from generation  63 :  11.000696378830083
# Distance from generation  64 :  11.000696378830083
# Distance from generation  65 :  11.000696378830083
# Distance from generation  66 :  11.000696378830083
# Distance from generation  67 :  11.000696378830083
# Distance from generation  68 :  11.000696378830083
# Distance from generation  69 :  11.000696378830083
# Distance from generation  70 :  11.000696378830083
# Distance from generation  71 :  11.000696378830083
# Distance from generation  72 :  11.000696378830083
# Distance from generation  73 :  11.000696378830083
# Distance from generation  74 :  11.000696378830083
# Distance from generation  75 :  11.000696378830083
# Distance from generation  76 :  11.000696378830083
# Distance from generation  77 :  11.000696378830083
# Distance from generation  78 :  11.000696378830083
# Distance from generation  79 :  11.000696378830083
# Distance from generation  80 :  11.000696378830083
# Distance from generation  81 :  11.000696378830083
# Distance from generation  82 :  11.000696378830083
# Distance from generation  83 :  11.000696378830083
# Distance from generation  84 :  11.000696378830083
# Distance from generation  85 :  11.000696378830083
# Distance from generation  86 :  11.000696378830083
# Distance from generation  87 :  11.000696378830083
# Distance from generation  88 :  11.000696378830083
# Distance from generation  89 :  11.000696378830083
# Distance from generation  90 :  11.000696378830083
# Distance from generation  91 :  11.000696378830083
# Distance from generation  92 :  11.000696378830083
# Distance from generation  93 :  11.000696378830083
# Distance from generation  94 :  11.000696378830083
# Distance from generation  95 :  11.000696378830083
# Distance from generation  96 :  11.000696378830083
# Distance from generation  97 :  11.000696378830083
# Distance from generation  98 :  11.000696378830083
# Distance from generation  99 :  11.000696378830083
# Distance from generation  100 :  11.000696378830083
# Distance from generation  101 :  11.000696378830083
# Distance from generation  102 :  11.000696378830083
# Distance from generation  103 :  11.000696378830083
# Distance from generation  104 :  11.000696378830083
# Distance from generation  105 :  11.000696378830083
# Distance from generation  106 :  11.000696378830083
# Distance from generation  107 :  11.000696378830083
# Distance from generation  108 :  11.000696378830083
# Distance from generation  109 :  11.000696378830083
# Distance from generation  110 :  11.000696378830083
# Distance from generation  111 :  11.000696378830083
# Distance from generation  112 :  11.000696378830083
# Distance from generation  113 :  11.000696378830083
# Distance from generation  114 :  11.000696378830083
# Distance from generation  115 :  11.000696378830083
# Distance from generation  116 :  11.000696378830083
# Distance from generation  117 :  11.000696378830083
# Distance from generation  118 :  11.000696378830083
# Distance from generation  119 :  11.000696378830083
# Distance from generation  120 :  11.000696378830083
# Distance from generation  121 :  11.000696378830083
# Distance from generation  122 :  11.000696378830083
# Distance from generation  123 :  11.000696378830083
# Distance from generation  124 :  11.000696378830083
# Distance from generation  125 :  11.000696378830083
# Distance from generation  126 :  11.000696378830083
# Distance from generation  127 :  11.000696378830083
# Distance from generation  128 :  11.000696378830083
# Distance from generation  129 :  11.000696378830083
# Distance from generation  130 :  11.000696378830083
# Distance from generation  131 :  11.000696378830083
# Distance from generation  132 :  11.000696378830083
# Distance from generation  133 :  11.000696378830083
# Distance from generation  134 :  11.000696378830083
# Distance from generation  135 :  11.000696378830083
# Distance from generation  136 :  11.000696378830083
# Distance from generation  137 :  11.000696378830083
# Distance from generation  138 :  11.000696378830083
# Distance from generation  139 :  11.000696378830083
# Distance from generation  140 :  11.000696378830083
# Distance from generation  141 :  11.000696378830083
# Distance from generation  142 :  11.000696378830083
# Distance from generation  143 :  11.000696378830083
# Distance from generation  144 :  11.000696378830083
# Distance from generation  145 :  11.000696378830083
# Distance from generation  146 :  11.000696378830083
# Distance from generation  147 :  11.000696378830083
# Distance from generation  148 :  11.000696378830083
# Distance from generation  149 :  11.000696378830083
# Distance from generation  150 :  11.000696378830083
# Distance from generation  151 :  11.000696378830083
# Distance from generation  152 :  11.000696378830083
# Distance from generation  153 :  11.000696378830083
# Distance from generation  154 :  11.000696378830083
# Distance from generation  155 :  11.000696378830083
# Distance from generation  156 :  11.000696378830083
# Distance from generation  157 :  11.000696378830083
# Distance from generation  158 :  11.000696378830083
# Distance from generation  159 :  11.000696378830083
# Distance from generation  160 :  11.000696378830083
# Distance from generation  161 :  11.000696378830083
# Distance from generation  162 :  11.000696378830083
# Distance from generation  163 :  11.000696378830083
# Distance from generation  164 :  11.000696378830083
# Distance from generation  165 :  11.000696378830083
# Distance from generation  166 :  11.000696378830083
# Distance from generation  167 :  11.000696378830083
# Distance from generation  168 :  11.000696378830083
# Distance from generation  169 :  11.000696378830083
# Distance from generation  170 :  11.000696378830083
# Distance from generation  171 :  11.000696378830083
# Distance from generation  172 :  11.000696378830083
# Distance from generation  173 :  11.000696378830083
# Distance from generation  174 :  11.000696378830083
# Distance from generation  175 :  11.000696378830083
# Distance from generation  176 :  11.000696378830083
# Distance from generation  177 :  11.000696378830083
# Distance from generation  178 :  11.000696378830083
# Distance from generation  179 :  11.000696378830083
# Distance from generation  180 :  11.000696378830083
# Distance from generation  181 :  11.000696378830083
# Distance from generation  182 :  11.000696378830083
# Distance from generation  183 :  11.000696378830083
# Distance from generation  184 :  11.000696378830083
# Distance from generation  185 :  11.000696378830083
# Distance from generation  186 :  11.000696378830083
# Distance from generation  187 :  11.000696378830083
# Distance from generation  188 :  11.000696378830083
# Distance from generation  189 :  11.000696378830083
# Distance from generation  190 :  11.000696378830083
# Distance from generation  191 :  11.000696378830083
# Distance from generation  192 :  11.000696378830083
# Distance from generation  193 :  11.000696378830083
# Distance from generation  194 :  11.000696378830083
# Distance from generation  195 :  11.000696378830083
# Distance from generation  196 :  11.000696378830083
# Distance from generation  197 :  11.000696378830083
# Distance from generation  198 :  11.000696378830083
# Distance from generation  199 :  11.000696378830083
# Distance from generation  200 :  11.000696378830083
# Distance from generation  201 :  11.000696378830083
# Distance from generation  202 :  11.000696378830083
# Distance from generation  203 :  11.000696378830083
# Distance from generation  204 :  11.000696378830083
# Distance from generation  205 :  11.000696378830083
# Distance from generation  206 :  11.000696378830083
# Distance from generation  207 :  11.000696378830083
# Distance from generation  208 :  11.000696378830083
# Distance from generation  209 :  11.000696378830083
# Distance from generation  210 :  11.000696378830083
# Distance from generation  211 :  11.000696378830083
# Distance from generation  212 :  11.000696378830083
# Distance from generation  213 :  11.000696378830083
# Distance from generation  214 :  11.000696378830083
# Distance from generation  215 :  11.000696378830083
# Distance from generation  216 :  11.000696378830083
# Distance from generation  217 :  11.000696378830083
# Distance from generation  218 :  11.000696378830083
# Distance from generation  219 :  11.000696378830083
# Distance from generation  220 :  11.000696378830083
# Distance from generation  221 :  11.000696378830083
# Distance from generation  222 :  11.000696378830083
# Distance from generation  223 :  11.000696378830083
# Distance from generation  224 :  11.000696378830083
# Distance from generation  225 :  11.000696378830083
# Distance from generation  226 :  11.000696378830083
# Distance from generation  227 :  11.000696378830083
# Distance from generation  228 :  11.000696378830083
# Distance from generation  229 :  11.000696378830083
# Distance from generation  230 :  11.000696378830083
# Distance from generation  231 :  11.000696378830083
# Distance from generation  232 :  11.000696378830083
# Distance from generation  233 :  11.000696378830083
# Distance from generation  234 :  11.000696378830083
# Distance from generation  235 :  11.000696378830083
# Distance from generation  236 :  11.000696378830083
# Distance from generation  237 :  11.000696378830083
# Distance from generation  238 :  11.000696378830083
# Distance from generation  239 :  11.000696378830083
# Distance from generation  240 :  11.000696378830083
# Distance from generation  241 :  11.000696378830083
# Distance from generation  242 :  11.000696378830083
# Distance from generation  243 :  11.000696378830083
# Distance from generation  244 :  11.000696378830083
# Distance from generation  245 :  11.000696378830083
# Distance from generation  246 :  11.000696378830083
# Distance from generation  247 :  11.000696378830083
# Distance from generation  248 :  11.000696378830083
# Distance from generation  249 :  11.000696378830083
# Distance from generation  250 :  11.000696378830083
# Distance from generation  251 :  11.000696378830083
# Distance from generation  252 :  11.000696378830083
# Distance from generation  253 :  11.000696378830083
# Distance from generation  254 :  11.000696378830083
# Distance from generation  255 :  11.000696378830083
# Distance from generation  256 :  11.000696378830083
# Distance from generation  257 :  11.000696378830083
# Distance from generation  258 :  11.000696378830083
# Distance from generation  259 :  11.000696378830083
# Distance from generation  260 :  11.000696378830083
# Distance from generation  261 :  11.000696378830083
# Distance from generation  262 :  11.000696378830083
# Distance from generation  263 :  11.000696378830083
# Distance from generation  264 :  11.000696378830083
# Distance from generation  265 :  11.000696378830083
# Distance from generation  266 :  11.000696378830083
# Distance from generation  267 :  11.000696378830083
# Distance from generation  268 :  11.000696378830083
# Distance from generation  269 :  11.000696378830083
# Distance from generation  270 :  11.000696378830083
# Distance from generation  271 :  11.000696378830083
# Distance from generation  272 :  11.000696378830083
# Distance from generation  273 :  11.000696378830083
# Distance from generation  274 :  11.000696378830083
# Distance from generation  275 :  11.000696378830083
# Distance from generation  276 :  11.000696378830083
# Distance from generation  277 :  11.000696378830083
# Distance from generation  278 :  11.000696378830083
# Distance from generation  279 :  11.000696378830083
# Distance from generation  280 :  11.000696378830083
# Distance from generation  281 :  11.000696378830083
# Distance from generation  282 :  11.000696378830083
# Distance from generation  283 :  11.000696378830083
# Distance from generation  284 :  11.000696378830083
# Distance from generation  285 :  11.000696378830083
# Distance from generation  286 :  11.000696378830083
# Distance from generation  287 :  11.000696378830083
# Distance from generation  288 :  11.000696378830083
# Distance from generation  289 :  11.000696378830083
# Distance from generation  290 :  11.000696378830083
# Distance from generation  291 :  11.000696378830083
# Distance from generation  292 :  11.000696378830083
# Distance from generation  293 :  11.000696378830083
# Distance from generation  294 :  11.000696378830083
# Distance from generation  295 :  11.000696378830083
# Distance from generation  296 :  11.000696378830083
# Distance from generation  297 :  11.000696378830083
# Distance from generation  298 :  11.000696378830083
# Distance from generation  299 :  11.000696378830083
# Distance from generation  300 :  11.000696378830083
# Distance from generation  301 :  11.000696378830083
# Distance from generation  302 :  11.000696378830083
# Distance from generation  303 :  11.000696378830083
# Distance from generation  304 :  11.000696378830083
# Distance from generation  305 :  11.000696378830083
# Distance from generation  306 :  11.000696378830083
# Distance from generation  307 :  11.000696378830083
# Distance from generation  308 :  11.000696378830083
# Distance from generation  309 :  11.000696378830083
# Distance from generation  310 :  11.000696378830083
# Distance from generation  311 :  11.000696378830083
# Distance from generation  312 :  11.000696378830083
# Distance from generation  313 :  11.000696378830083
# Distance from generation  314 :  11.000696378830083
# Distance from generation  315 :  11.000696378830083
# Distance from generation  316 :  11.000696378830083
# Distance from generation  317 :  11.000696378830083
# Distance from generation  318 :  11.000696378830083
# Distance from generation  319 :  11.000696378830083
# Distance from generation  320 :  11.000696378830083
# Distance from generation  321 :  11.000696378830083
# Distance from generation  322 :  11.000696378830083
# Distance from generation  323 :  11.000696378830083
# Distance from generation  324 :  11.000696378830083
# Distance from generation  325 :  11.000696378830083
# Distance from generation  326 :  11.000696378830083
# Distance from generation  327 :  11.000696378830083
# Distance from generation  328 :  11.000696378830083
# Distance from generation  329 :  11.000696378830083
# Distance from generation  330 :  11.000696378830083
# Distance from generation  331 :  11.000696378830083
# Distance from generation  332 :  11.000696378830083
# Distance from generation  333 :  11.000696378830083
# Distance from generation  334 :  11.000696378830083
# Distance from generation  335 :  11.000696378830083
# Distance from generation  336 :  11.000696378830083
# Distance from generation  337 :  11.000696378830083
# Distance from generation  338 :  11.000696378830083
# Distance from generation  339 :  11.000696378830083
# Distance from generation  340 :  11.000696378830083
# Distance from generation  341 :  11.000696378830083
# Distance from generation  342 :  11.000696378830083
# Distance from generation  343 :  11.000696378830083
# Distance from generation  344 :  11.000696378830083
# Distance from generation  345 :  11.000696378830083
# Distance from generation  346 :  11.000696378830083
# Distance from generation  347 :  11.000696378830083
# Distance from generation  348 :  11.000696378830083
# Distance from generation  349 :  11.000696378830083
# Distance from generation  350 :  11.000696378830083
# Distance from generation  351 :  11.000696378830083
# Distance from generation  352 :  11.000696378830083
# Distance from generation  353 :  11.000696378830083
# Distance from generation  354 :  11.000696378830083
# Distance from generation  355 :  11.000696378830083
# Distance from generation  356 :  11.000696378830083
# Distance from generation  357 :  11.000696378830083
# Distance from generation  358 :  11.000696378830083
# Distance from generation  359 :  11.000696378830083
# Distance from generation  360 :  11.000696378830083
# Distance from generation  361 :  11.000696378830083
# Distance from generation  362 :  11.000696378830083
# Distance from generation  363 :  11.000696378830083
# Distance from generation  364 :  11.000696378830083
# Distance from generation  365 :  11.000696378830083
# Distance from generation  366 :  11.000696378830083
# Distance from generation  367 :  11.000696378830083
# Distance from generation  368 :  11.000696378830083
# Distance from generation  369 :  11.000696378830083
# Distance from generation  370 :  11.000696378830083
# Distance from generation  371 :  11.000696378830083
# Distance from generation  372 :  11.000696378830083
# Distance from generation  373 :  11.000696378830083
# Distance from generation  374 :  11.000696378830083
# Distance from generation  375 :  11.000696378830083
# Distance from generation  376 :  11.000696378830083
# Distance from generation  377 :  11.000696378830083
# Distance from generation  378 :  11.000696378830083
# Distance from generation  379 :  11.000696378830083
# Distance from generation  380 :  11.000696378830083
# Distance from generation  381 :  11.000696378830083
# Distance from generation  382 :  11.000696378830083
# Distance from generation  383 :  11.000696378830083
# Distance from generation  384 :  11.000696378830083
# Distance from generation  385 :  11.000696378830083
# Distance from generation  386 :  11.000696378830083
# Distance from generation  387 :  11.000696378830083
# Distance from generation  388 :  11.000696378830083
# Distance from generation  389 :  11.000696378830083
# Distance from generation  390 :  11.000696378830083
# Distance from generation  391 :  11.000696378830083
# Distance from generation  392 :  11.000696378830083
# Distance from generation  393 :  11.000696378830083
# Distance from generation  394 :  11.000696378830083
# Distance from generation  395 :  11.000696378830083
# Distance from generation  396 :  11.000696378830083
# Distance from generation  397 :  11.000696378830083
# Distance from generation  398 :  11.000696378830083
# Distance from generation  399 :  11.000696378830083
# Distance from generation  400 :  11.000696378830083
# Distance from generation  401 :  11.000696378830083
# Distance from generation  402 :  11.000696378830083
# Distance from generation  403 :  11.000696378830083
# Distance from generation  404 :  11.000696378830083
# Distance from generation  405 :  11.000696378830083
# Distance from generation  406 :  11.000696378830083
# Distance from generation  407 :  11.000696378830083
# Distance from generation  408 :  11.000696378830083
# Distance from generation  409 :  11.000696378830083
# Distance from generation  410 :  11.000696378830083
# Distance from generation  411 :  11.000696378830083
# Distance from generation  412 :  11.000696378830083
# Distance from generation  413 :  11.000696378830083
# Distance from generation  414 :  11.000696378830083
# Distance from generation  415 :  11.000696378830083
# Distance from generation  416 :  11.000696378830083
# Distance from generation  417 :  11.000696378830083
# Distance from generation  418 :  11.000696378830083
# Distance from generation  419 :  11.000696378830083
# Distance from generation  420 :  11.000696378830083
# Distance from generation  421 :  11.000696378830083
# Distance from generation  422 :  11.000696378830083
# Distance from generation  423 :  11.000696378830083
# Distance from generation  424 :  11.000696378830083
# Distance from generation  425 :  11.000696378830083
# Distance from generation  426 :  11.000696378830083
# Distance from generation  427 :  11.000696378830083
# Distance from generation  428 :  11.000696378830083
# Distance from generation  429 :  11.000696378830083
# Distance from generation  430 :  11.000696378830083
# Distance from generation  431 :  11.000696378830083
# Distance from generation  432 :  11.000696378830083
# Distance from generation  433 :  11.000696378830083
# Distance from generation  434 :  11.000696378830083
# Distance from generation  435 :  11.000696378830083
# Distance from generation  436 :  11.000696378830083
# Distance from generation  437 :  11.000696378830083
# Distance from generation  438 :  11.000696378830083
# Distance from generation  439 :  11.000696378830083
# Distance from generation  440 :  11.000696378830083
# Distance from generation  441 :  11.000696378830083
# Distance from generation  442 :  11.000696378830083
# Distance from generation  443 :  11.000696378830083
# Distance from generation  444 :  11.000696378830083
# Distance from generation  445 :  11.000696378830083
# Distance from generation  446 :  11.000696378830083
# Distance from generation  447 :  11.000696378830083
# Distance from generation  448 :  11.000696378830083
# Distance from generation  449 :  11.000696378830083
# Distance from generation  450 :  11.000696378830083
# Distance from generation  451 :  11.000696378830083
# Distance from generation  452 :  11.000696378830083
# Distance from generation  453 :  11.000696378830083
# Distance from generation  454 :  11.000696378830083
# Distance from generation  455 :  11.000696378830083
# Distance from generation  456 :  11.000696378830083
# Distance from generation  457 :  11.000696378830083
# Distance from generation  458 :  11.000696378830083
# Distance from generation  459 :  11.000696378830083
# Distance from generation  460 :  11.000696378830083
# Distance from generation  461 :  11.000696378830083
# Distance from generation  462 :  11.000696378830083
# Distance from generation  463 :  11.000696378830083
# Distance from generation  464 :  11.000696378830083
# Distance from generation  465 :  11.000696378830083
# Distance from generation  466 :  11.000696378830083
# Distance from generation  467 :  11.000696378830083
# Distance from generation  468 :  11.000696378830083
# Distance from generation  469 :  11.000696378830083
# Distance from generation  470 :  11.000696378830083
# Distance from generation  471 :  11.000696378830083
# Distance from generation  472 :  11.000696378830083
# Distance from generation  473 :  11.000696378830083
# Distance from generation  474 :  11.000696378830083
# Distance from generation  475 :  11.000696378830083
# Distance from generation  476 :  11.000696378830083
# Distance from generation  477 :  11.000696378830083
# Distance from generation  478 :  11.000696378830083
# Distance from generation  479 :  11.000696378830083
# Distance from generation  480 :  11.000696378830083
# Distance from generation  481 :  11.000696378830083
# Distance from generation  482 :  11.000696378830083
# Distance from generation  483 :  11.000696378830083
# Distance from generation  484 :  11.000696378830083
# Distance from generation  485 :  11.000696378830083
# Distance from generation  486 :  11.000696378830083
# Distance from generation  487 :  11.000696378830083
# Distance from generation  488 :  11.000696378830083
# Distance from generation  489 :  11.000696378830083
# Distance from generation  490 :  11.000696378830083
# Distance from generation  491 :  11.000696378830083
# Distance from generation  492 :  11.000696378830083
# Distance from generation  493 :  11.000696378830083
# Distance from generation  494 :  11.000696378830083
# Distance from generation  495 :  11.000696378830083
# Distance from generation  496 :  11.000696378830083
# Distance from generation  497 :  11.000696378830083
# Distance from generation  498 :  11.000696378830083
# Distance from generation  499 :  11.000696378830083
# Distance from generation  500 :  11.000696378830083
# Distance from generation  501 :  11.000696378830083
# Distance from generation  502 :  11.000696378830083
# Distance from generation  503 :  11.000696378830083
# Distance from generation  504 :  11.000696378830083
# Distance from generation  505 :  11.000696378830083
# Distance from generation  506 :  11.000696378830083
# Distance from generation  507 :  11.000696378830083
# Distance from generation  508 :  11.000696378830083
# Distance from generation  509 :  11.000696378830083
# Distance from generation  510 :  11.000696378830083
# Distance from generation  511 :  11.000696378830083
# Distance from generation  512 :  11.000696378830083
# Distance from generation  513 :  11.000696378830083
# Distance from generation  514 :  11.000696378830083
# Distance from generation  515 :  11.000696378830083
# Distance from generation  516 :  11.000696378830083
# Distance from generation  517 :  11.000696378830083
# Distance from generation  518 :  11.000696378830083
# Distance from generation  519 :  11.000696378830083
# Distance from generation  520 :  11.000696378830083
# Distance from generation  521 :  11.000696378830083
# Distance from generation  522 :  11.000696378830083
# Distance from generation  523 :  11.000696378830083
# Distance from generation  524 :  11.000696378830083
# Distance from generation  525 :  11.000696378830083
# Distance from generation  526 :  11.000696378830083
# Distance from generation  527 :  11.000696378830083
# Distance from generation  528 :  11.000696378830083
# Distance from generation  529 :  11.000696378830083
# Distance from generation  530 :  11.000696378830083
# Distance from generation  531 :  11.000696378830083
# Distance from generation  532 :  11.000696378830083
# Distance from generation  533 :  11.000696378830083
# Distance from generation  534 :  11.000696378830083
# Distance from generation  535 :  11.000696378830083
# Distance from generation  536 :  11.000696378830083
# Distance from generation  537 :  11.000696378830083
# Distance from generation  538 :  11.000696378830083
# Distance from generation  539 :  11.000696378830083
# Distance from generation  540 :  11.000696378830083
# Distance from generation  541 :  11.000696378830083
# Distance from generation  542 :  11.000696378830083
# Distance from generation  543 :  11.000696378830083
# Distance from generation  544 :  11.000696378830083
# Distance from generation  545 :  11.000696378830083
# Distance from generation  546 :  11.000696378830083
# Distance from generation  547 :  11.000696378830083
# Distance from generation  548 :  11.000696378830083
# Distance from generation  549 :  11.000696378830083
# Distance from generation  550 :  11.000696378830083
# Distance from generation  551 :  11.000696378830083
# Distance from generation  552 :  11.000696378830083
# Distance from generation  553 :  11.000696378830083
# Distance from generation  554 :  11.000696378830083
# Distance from generation  555 :  11.000696378830083
# Distance from generation  556 :  11.000696378830083
# Distance from generation  557 :  11.000696378830083
# Distance from generation  558 :  11.000696378830083
# Distance from generation  559 :  11.000696378830083
# Distance from generation  560 :  11.000696378830083
# Distance from generation  561 :  11.000696378830083
# Distance from generation  562 :  11.000696378830083
# Distance from generation  563 :  11.000696378830083
# Distance from generation  564 :  11.000696378830083
# Distance from generation  565 :  11.000696378830083
# Distance from generation  566 :  11.000696378830083
# Distance from generation  567 :  11.000696378830083
# Distance from generation  568 :  11.000696378830083
# Distance from generation  569 :  11.000696378830083
# Distance from generation  570 :  11.000696378830083
# Distance from generation  571 :  11.000696378830083
# Distance from generation  572 :  11.000696378830083
# Distance from generation  573 :  11.000696378830083
# Distance from generation  574 :  11.000696378830083
# Distance from generation  575 :  11.000696378830083
# Distance from generation  576 :  11.000696378830083
# Distance from generation  577 :  11.000696378830083
# Distance from generation  578 :  11.000696378830083
# Distance from generation  579 :  11.000696378830083
# Distance from generation  580 :  11.000696378830083
# Distance from generation  581 :  11.000696378830083
# Distance from generation  582 :  11.000696378830083
# Distance from generation  583 :  11.000696378830083
# Distance from generation  584 :  11.000696378830083
# Distance from generation  585 :  11.000696378830083
# Distance from generation  586 :  11.000696378830083
# Distance from generation  587 :  11.000696378830083
# Distance from generation  588 :  11.000696378830083
# Distance from generation  589 :  11.000696378830083
# Distance from generation  590 :  11.000696378830083
# Distance from generation  591 :  11.000696378830083
# Distance from generation  592 :  11.000696378830083
# Distance from generation  593 :  11.000696378830083
# Distance from generation  594 :  11.000696378830083
# Distance from generation  595 :  11.000696378830083
# Distance from generation  596 :  11.000696378830083
# Distance from generation  597 :  11.000696378830083
# Distance from generation  598 :  11.000696378830083
# Distance from generation  599 :  11.000696378830083
# Distance from generation  600 :  11.000696378830083
# Distance from generation  601 :  11.000696378830083
# Distance from generation  602 :  11.000696378830083
# Distance from generation  603 :  11.000696378830083
# Distance from generation  604 :  11.000696378830083
# Distance from generation  605 :  11.000696378830083
# Distance from generation  606 :  11.000696378830083
# Distance from generation  607 :  11.000696378830083
# Distance from generation  608 :  11.000696378830083
# Distance from generation  609 :  11.000696378830083
# Distance from generation  610 :  11.000696378830083
# Distance from generation  611 :  11.000696378830083
# Distance from generation  612 :  11.000696378830083
# Distance from generation  613 :  11.000696378830083
# Distance from generation  614 :  11.000696378830083
# Distance from generation  615 :  11.000696378830083
# Distance from generation  616 :  11.000696378830083
# Distance from generation  617 :  11.000696378830083
# Distance from generation  618 :  11.000696378830083
# Distance from generation  619 :  11.000696378830083
# Distance from generation  620 :  11.000696378830083
# Distance from generation  621 :  11.000696378830083
# Distance from generation  622 :  11.000696378830083
# Distance from generation  623 :  11.000696378830083
# Distance from generation  624 :  11.000696378830083
# Distance from generation  625 :  11.000696378830083
# Distance from generation  626 :  11.000696378830083
# Distance from generation  627 :  11.000696378830083
# Distance from generation  628 :  11.000696378830083
# Distance from generation  629 :  11.000696378830083
# Distance from generation  630 :  11.000696378830083
# Distance from generation  631 :  11.000696378830083
# Distance from generation  632 :  11.000696378830083
# Distance from generation  633 :  11.000696378830083
# Distance from generation  634 :  11.000696378830083
# Distance from generation  635 :  11.000696378830083
# Distance from generation  636 :  11.000696378830083
# Distance from generation  637 :  11.000696378830083
# Distance from generation  638 :  11.000696378830083
# Distance from generation  639 :  11.000696378830083
# Distance from generation  640 :  11.000696378830083
# Distance from generation  641 :  11.000696378830083
# Distance from generation  642 :  11.000696378830083
# Distance from generation  643 :  11.000696378830083
# Distance from generation  644 :  11.000696378830083
# Distance from generation  645 :  11.000696378830083
# Distance from generation  646 :  11.000696378830083
# Distance from generation  647 :  11.000696378830083
# Distance from generation  648 :  11.000696378830083
# Distance from generation  649 :  11.000696378830083
# Distance from generation  650 :  11.000696378830083
# Distance from generation  651 :  11.000696378830083
# Distance from generation  652 :  11.000696378830083
# Distance from generation  653 :  11.000696378830083
# Distance from generation  654 :  11.000696378830083
# Distance from generation  655 :  11.000696378830083
# Distance from generation  656 :  11.000696378830083
# Distance from generation  657 :  11.000696378830083
# Distance from generation  658 :  11.000696378830083
# Distance from generation  659 :  11.000696378830083
# Distance from generation  660 :  11.000696378830083
# Distance from generation  661 :  11.000696378830083
# Distance from generation  662 :  11.000696378830083
# Distance from generation  663 :  11.000696378830083
# Distance from generation  664 :  11.000696378830083
# Distance from generation  665 :  11.000696378830083
# Distance from generation  666 :  11.000696378830083
# Distance from generation  667 :  11.000696378830083
# Distance from generation  668 :  11.000696378830083
# Distance from generation  669 :  11.000696378830083
# Distance from generation  670 :  11.000696378830083
# Distance from generation  671 :  11.000696378830083
# Distance from generation  672 :  11.000696378830083
# Distance from generation  673 :  11.000696378830083
# Distance from generation  674 :  11.000696378830083
# Distance from generation  675 :  11.000696378830083
# Distance from generation  676 :  11.000696378830083
# Distance from generation  677 :  11.000696378830083
# Distance from generation  678 :  11.000696378830083
# Distance from generation  679 :  11.000696378830083
# Distance from generation  680 :  11.000696378830083
# Distance from generation  681 :  11.000696378830083
# Distance from generation  682 :  11.000696378830083
# Distance from generation  683 :  11.000696378830083
# Distance from generation  684 :  11.000696378830083
# Distance from generation  685 :  11.000696378830083
# Distance from generation  686 :  11.000696378830083
# Distance from generation  687 :  11.000696378830083
# Distance from generation  688 :  11.000696378830083
# Distance from generation  689 :  11.000696378830083
# Distance from generation  690 :  11.000696378830083
# Distance from generation  691 :  11.000696378830083
# Distance from generation  692 :  11.000696378830083
# Distance from generation  693 :  11.000696378830083
# Distance from generation  694 :  11.000696378830083
# Distance from generation  695 :  11.000696378830083
# Distance from generation  696 :  11.000696378830083
# Distance from generation  697 :  11.000696378830083
# Distance from generation  698 :  11.000696378830083
# Distance from generation  699 :  11.000696378830083
# Distance from generation  700 :  11.000696378830083
# Distance from generation  701 :  11.000696378830083
# Distance from generation  702 :  11.000696378830083
# Distance from generation  703 :  11.000696378830083
# Distance from generation  704 :  11.000696378830083
# Distance from generation  705 :  11.000696378830083
# Distance from generation  706 :  11.000696378830083
# Distance from generation  707 :  11.000696378830083
# Distance from generation  708 :  11.000696378830083
# Distance from generation  709 :  11.000696378830083
# Distance from generation  710 :  11.000696378830083
# Distance from generation  711 :  11.000696378830083
# Distance from generation  712 :  11.000696378830083
# Distance from generation  713 :  11.000696378830083
# Distance from generation  714 :  11.000696378830083
# Distance from generation  715 :  11.000696378830083
# Distance from generation  716 :  11.000696378830083
# Distance from generation  717 :  11.000696378830083
# Distance from generation  718 :  11.000696378830083
# Distance from generation  719 :  11.000696378830083
# Distance from generation  720 :  11.000696378830083
# Distance from generation  721 :  11.000696378830083
# Distance from generation  722 :  11.000696378830083
# Distance from generation  723 :  11.000696378830083
# Distance from generation  724 :  11.000696378830083
# Distance from generation  725 :  11.000696378830083
# Distance from generation  726 :  11.000696378830083
# Distance from generation  727 :  11.000696378830083
# Distance from generation  728 :  11.000696378830083
# Distance from generation  729 :  11.000696378830083
# Distance from generation  730 :  11.000696378830083
# Distance from generation  731 :  11.000696378830083
# Distance from generation  732 :  11.000696378830083
# Distance from generation  733 :  11.000696378830083
# Distance from generation  734 :  11.000696378830083
# Distance from generation  735 :  11.000696378830083
# Distance from generation  736 :  11.000696378830083
# Distance from generation  737 :  11.000696378830083
# Distance from generation  738 :  11.000696378830083
# Distance from generation  739 :  11.000696378830083
# Distance from generation  740 :  11.000696378830083
# Distance from generation  741 :  11.000696378830083
# Distance from generation  742 :  11.000696378830083
# Distance from generation  743 :  11.000696378830083
# Distance from generation  744 :  11.000696378830083
# Distance from generation  745 :  11.000696378830083
# Distance from generation  746 :  11.000696378830083
# Distance from generation  747 :  11.000696378830083
# Distance from generation  748 :  11.000696378830083
# Distance from generation  749 :  11.000696378830083
# Distance from generation  750 :  11.000696378830083
# Distance from generation  751 :  11.000696378830083
# Distance from generation  752 :  11.000696378830083
# Distance from generation  753 :  11.000696378830083
# Distance from generation  754 :  11.000696378830083
# Distance from generation  755 :  11.000696378830083
# Distance from generation  756 :  11.000696378830083
# Distance from generation  757 :  11.000696378830083
# Distance from generation  758 :  11.000696378830083
# Distance from generation  759 :  11.000696378830083
# Distance from generation  760 :  11.000696378830083
# Distance from generation  761 :  11.000696378830083
# Distance from generation  762 :  11.000696378830083
# Distance from generation  763 :  11.000696378830083
# Distance from generation  764 :  11.000696378830083
# Distance from generation  765 :  11.000696378830083
# Distance from generation  766 :  11.000696378830083
# Distance from generation  767 :  11.000696378830083
# Distance from generation  768 :  11.000696378830083
# Distance from generation  769 :  11.000696378830083
# Distance from generation  770 :  11.000696378830083
# Distance from generation  771 :  11.000696378830083
# Distance from generation  772 :  11.000696378830083
# Distance from generation  773 :  11.000696378830083
# Distance from generation  774 :  11.000696378830083
# Distance from generation  775 :  11.000696378830083
# Distance from generation  776 :  11.000696378830083
# Distance from generation  777 :  11.000696378830083
# Distance from generation  778 :  11.000696378830083
# Distance from generation  779 :  11.000696378830083
# Distance from generation  780 :  11.000696378830083
# Distance from generation  781 :  11.000696378830083
# Distance from generation  782 :  11.000696378830083
# Distance from generation  783 :  11.000696378830083
# Distance from generation  784 :  11.000696378830083
# Distance from generation  785 :  11.000696378830083
# Distance from generation  786 :  11.000696378830083
# Distance from generation  787 :  11.000696378830083
# Distance from generation  788 :  11.000696378830083
# Distance from generation  789 :  11.000696378830083
# Distance from generation  790 :  11.000696378830083
# Distance from generation  791 :  11.000696378830083
# Distance from generation  792 :  11.000696378830083
# Distance from generation  793 :  11.000696378830083
# Distance from generation  794 :  11.000696378830083
# Distance from generation  795 :  11.000696378830083
# Distance from generation  796 :  11.000696378830083
# Distance from generation  797 :  11.000696378830083
# Distance from generation  798 :  11.000696378830083
# Distance from generation  799 :  11.000696378830083
# Distance from generation  800 :  11.000696378830083
# Distance from generation  801 :  11.000696378830083
# Distance from generation  802 :  11.000696378830083
# Distance from generation  803 :  11.000696378830083
# Distance from generation  804 :  11.000696378830083
# Distance from generation  805 :  11.000696378830083
# Distance from generation  806 :  11.000696378830083
# Distance from generation  807 :  11.000696378830083
# Distance from generation  808 :  11.000696378830083
# Distance from generation  809 :  11.000696378830083
# Distance from generation  810 :  11.000696378830083
# Distance from generation  811 :  11.000696378830083
# Distance from generation  812 :  11.000696378830083
# Distance from generation  813 :  11.000696378830083
# Distance from generation  814 :  11.000696378830083
# Distance from generation  815 :  11.000696378830083
# Distance from generation  816 :  11.000696378830083
# Distance from generation  817 :  11.000696378830083
# Distance from generation  818 :  11.000696378830083
# Distance from generation  819 :  11.000696378830083
# Distance from generation  820 :  11.000696378830083
# Distance from generation  821 :  11.000696378830083
# Distance from generation  822 :  11.000696378830083
# Distance from generation  823 :  11.000696378830083
# Distance from generation  824 :  11.000696378830083
# Distance from generation  825 :  11.000696378830083
# Distance from generation  826 :  11.000696378830083
# Distance from generation  827 :  11.000696378830083
# Distance from generation  828 :  11.000696378830083
# Distance from generation  829 :  11.000696378830083
# Distance from generation  830 :  11.000696378830083
# Distance from generation  831 :  11.000696378830083
# Distance from generation  832 :  11.000696378830083
# Distance from generation  833 :  11.000696378830083
# Distance from generation  834 :  11.000696378830083
# Distance from generation  835 :  11.000696378830083
# Distance from generation  836 :  11.000696378830083
# Distance from generation  837 :  11.000696378830083
# Distance from generation  838 :  11.000696378830083
# Distance from generation  839 :  11.000696378830083
# Distance from generation  840 :  11.000696378830083
# Distance from generation  841 :  11.000696378830083
# Distance from generation  842 :  11.000696378830083
# Distance from generation  843 :  11.000696378830083
# Distance from generation  844 :  11.000696378830083
# Distance from generation  845 :  11.000696378830083
# Distance from generation  846 :  11.000696378830083
# Distance from generation  847 :  11.000696378830083
# Distance from generation  848 :  11.000696378830083
# Distance from generation  849 :  11.000696378830083
# Distance from generation  850 :  11.000696378830083
# Distance from generation  851 :  11.000696378830083
# Distance from generation  852 :  11.000696378830083
# Distance from generation  853 :  11.000696378830083
# Distance from generation  854 :  11.000696378830083
# Distance from generation  855 :  11.000696378830083
# Distance from generation  856 :  11.000696378830083
# Distance from generation  857 :  11.000696378830083
# Distance from generation  858 :  11.000696378830083
# Distance from generation  859 :  11.000696378830083
# Distance from generation  860 :  11.000696378830083
# Distance from generation  861 :  11.000696378830083
# Distance from generation  862 :  11.000696378830083
# Distance from generation  863 :  11.000696378830083
# Distance from generation  864 :  11.000696378830083
# Distance from generation  865 :  11.000696378830083
# Distance from generation  866 :  11.000696378830083
# Distance from generation  867 :  11.000696378830083
# Distance from generation  868 :  11.000696378830083
# Distance from generation  869 :  11.000696378830083
# Distance from generation  870 :  11.000696378830083
# Distance from generation  871 :  11.000696378830083
# Distance from generation  872 :  11.000696378830083
# Distance from generation  873 :  11.000696378830083
# Distance from generation  874 :  11.000696378830083
# Distance from generation  875 :  11.000696378830083
# Distance from generation  876 :  11.000696378830083
# Distance from generation  877 :  11.000696378830083
# Distance from generation  878 :  11.000696378830083
# Distance from generation  879 :  11.000696378830083
# Distance from generation  880 :  11.000696378830083
# Distance from generation  881 :  11.000696378830083
# Distance from generation  882 :  11.000696378830083
# Distance from generation  883 :  11.000696378830083
# Distance from generation  884 :  11.000696378830083
# Distance from generation  885 :  11.000696378830083
# Distance from generation  886 :  11.000696378830083
# Distance from generation  887 :  11.000696378830083
# Distance from generation  888 :  11.000696378830083
# Distance from generation  889 :  11.000696378830083
# Distance from generation  890 :  11.000696378830083
# Distance from generation  891 :  11.000696378830083
# Distance from generation  892 :  11.000696378830083
# Distance from generation  893 :  11.000696378830083
# Distance from generation  894 :  11.000696378830083
# Distance from generation  895 :  11.000696378830083
# Distance from generation  896 :  11.000696378830083
# Distance from generation  897 :  11.000696378830083
# Distance from generation  898 :  11.000696378830083
# Distance from generation  899 :  11.000696378830083
# Distance from generation  900 :  11.000696378830083
# Distance from generation  901 :  11.000696378830083
# Distance from generation  902 :  11.000696378830083
# Distance from generation  903 :  11.000696378830083
# Distance from generation  904 :  11.000696378830083
# Distance from generation  905 :  11.000696378830083
# Distance from generation  906 :  11.000696378830083
# Distance from generation  907 :  11.000696378830083
# Distance from generation  908 :  11.000696378830083
# Distance from generation  909 :  11.000696378830083
# Distance from generation  910 :  11.000696378830083
# Distance from generation  911 :  11.000696378830083
# Distance from generation  912 :  11.000696378830083
# Distance from generation  913 :  11.000696378830083
# Distance from generation  914 :  11.000696378830083
# Distance from generation  915 :  11.000696378830083
# Distance from generation  916 :  11.000696378830083
# Distance from generation  917 :  11.000696378830083
# Distance from generation  918 :  11.000696378830083
# Distance from generation  919 :  11.000696378830083
# Distance from generation  920 :  11.000696378830083
# Distance from generation  921 :  11.000696378830083
# Distance from generation  922 :  11.000696378830083
# Distance from generation  923 :  11.000696378830083
# Distance from generation  924 :  11.000696378830083
# Distance from generation  925 :  11.000696378830083
# Distance from generation  926 :  11.000696378830083
# Distance from generation  927 :  11.000696378830083
# Distance from generation  928 :  11.000696378830083
# Distance from generation  929 :  11.000696378830083
# Distance from generation  930 :  11.000696378830083
# Distance from generation  931 :  11.000696378830083
# Distance from generation  932 :  11.000696378830083
# Distance from generation  933 :  11.000696378830083
# Distance from generation  934 :  11.000696378830083
# Distance from generation  935 :  11.000696378830083
# Distance from generation  936 :  11.000696378830083
# Distance from generation  937 :  11.000696378830083
# Distance from generation  938 :  11.000696378830083
# Distance from generation  939 :  11.000696378830083
# Distance from generation  940 :  11.000696378830083
# Distance from generation  941 :  11.000696378830083
# Distance from generation  942 :  11.000696378830083
# Distance from generation  943 :  11.000696378830083
# Distance from generation  944 :  11.000696378830083
# Distance from generation  945 :  11.000696378830083
# Distance from generation  946 :  11.000696378830083
# Distance from generation  947 :  11.000696378830083
# Distance from generation  948 :  11.000696378830083
# Distance from generation  949 :  11.000696378830083
# Distance from generation  950 :  11.000696378830083
# Distance from generation  951 :  11.000696378830083
# Distance from generation  952 :  11.000696378830083
# Distance from generation  953 :  11.000696378830083
# Distance from generation  954 :  11.000696378830083
# Distance from generation  955 :  11.000696378830083
# Distance from generation  956 :  11.000696378830083
# Distance from generation  957 :  11.000696378830083
# Distance from generation  958 :  11.000696378830083
# Distance from generation  959 :  11.000696378830083
# Distance from generation  960 :  11.000696378830083
# Distance from generation  961 :  11.000696378830083
# Distance from generation  962 :  11.000696378830083
# Distance from generation  963 :  11.000696378830083
# Distance from generation  964 :  11.000696378830083
# Distance from generation  965 :  11.000696378830083
# Distance from generation  966 :  11.000696378830083
# Distance from generation  967 :  11.000696378830083
# Distance from generation  968 :  11.000696378830083
# Distance from generation  969 :  11.000696378830083
# Distance from generation  970 :  11.000696378830083
# Distance from generation  971 :  11.000696378830083
# Distance from generation  972 :  11.000696378830083
# Distance from generation  973 :  11.000696378830083
# Distance from generation  974 :  11.000696378830083
# Distance from generation  975 :  11.000696378830083
# Distance from generation  976 :  11.000696378830083
# Distance from generation  977 :  11.000696378830083
# Distance from generation  978 :  11.000696378830083
# Distance from generation  979 :  11.000696378830083
# Distance from generation  980 :  11.000696378830083
# Distance from generation  981 :  11.000696378830083
# Distance from generation  982 :  11.000696378830083
# Distance from generation  983 :  11.000696378830083
# Distance from generation  984 :  11.000696378830083
# Distance from generation  985 :  11.000696378830083
# Distance from generation  986 :  11.000696378830083
# Distance from generation  987 :  11.000696378830083
# Distance from generation  988 :  11.000696378830083
# Distance from generation  989 :  11.000696378830083
# Distance from generation  990 :  11.000696378830083
# Distance from generation  991 :  11.000696378830083
# Distance from generation  992 :  11.000696378830083
# Distance from generation  993 :  11.000696378830083
# Distance from generation  994 :  11.000696378830083
# Distance from generation  995 :  11.000696378830083
# Distance from generation  996 :  11.000696378830083
# Distance from generation  997 :  11.000696378830083
# Distance from generation  998 :  11.000696378830083
# Distance from generation  999 :  11.000696378830083
# Distance from generation  1000 :  11.000696378830083
# Final distance: {'path': ['ROM', 'MIL', 'LYO', 'BAR', 'MAD', 'PAR', 'BRU', 'AMS', 'COL', 'FRA', 'BER'], 'time': 1578, 'cost': 1436, 'fitness': 11.000696378830083}
# {'path': ['ROM',
#   'MIL',
#   'LYO',
#   'BAR',
#   'MAD',
#   'PAR',
#   'BRU',
#   'AMS',
#   'COL',
#   'FRA',
#   'BER'],
#  'time': 1578,
#  'cost': 1436,
#  'fitness': 11.000696378830083}
